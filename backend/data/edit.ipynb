# %%
import pandas as pd

# Read your CSV file (replace 'your_file.csv' with your actual filename)
df = pd.read_csv('ratings.csv', header=None)

# Define your column headers
headers = ['product_id', 'user_id', 'rating', 'timestamp']

# Assign the headers to the dataframe
df.columns = headers

# Save it back to CSV
df.to_csv('rating.csv', index=False)

print("Headers added successfully!")
# Out:
# Headers added successfully!
